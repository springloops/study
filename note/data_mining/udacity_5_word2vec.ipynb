# %% [markdown]
# https://github.com/tensorflow/tensorflow/blob/master/tensorflow/examples/udacity/5_word2vec.ipynb

# %%
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
    """Download a file if not present, and make sure it's the right size."""
    if not os.path.exists(filename):
        filename, _ = urlretrieve(url + filename, filename)
    statinfo = os.stat(filename)    
    if statinfo.st_size == expected_bytes:
        print('Found and verified %s' % filename)
    else:
        print(statinfo.st_size)
        raise Exception('Failed to verify ' + filename + '. Can you get to it with a browser?')
    return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
    return data

words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %%
print(type(words))
print(words[1])
# Out:
# <class 'list'>
# originated

# %%
vocabulary_size = 50000

def build_dataset(words):
    count = [['UNK', -1]]
    count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
    dictionary = dict()
    for word, _ in count:
        dictionary[word] = len(dictionary)
    data = list()
    unk_count = 0
    for word in words:
        if word in dictionary:
            index = dictionary[word]
        else:
            index = 0  # dictionary['UNK']
            unk_count = unk_count + 1
        data.append(index)
    count[0][1] = unk_count
    reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
    return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5234, 3081, 12, 6, 195, 2, 3134, 46, 59, 156]

# %%
print(data[:10])
print(count[:10])
print(dictionary['kuznetsova'])
print(reverse_dictionary[49891])
# Out:
# [5234, 3081, 12, 6, 195, 2, 3134, 46, 59, 156]
# [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764), ('in', 372201), ('a', 325873), ('to', 316376), ('zero', 264975), ('nine', 250430)]
# 49891
# kuznetsova

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
    global data_index
    assert batch_size % num_skips == 0
    assert num_skips <= 2 * skip_window
    batch = np.ndarray(shape=(batch_size), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    span = 2 * skip_window + 1 # [ skip_window target skip_window ]
    buffer = collections.deque(maxlen=span)
    for _ in range(span):
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
         
    for i in range(batch_size // num_skips):
        target = skip_window  # target label at the center of the buffer
        targets_to_avoid = [ skip_window ]
        for j in range(num_skips):
            while target in targets_to_avoid:
                target = random.randint(0, span - 1)
            targets_to_avoid.append(target)
            batch[i * num_skips + j] = buffer[skip_window]
            labels[i * num_skips + j, 0] = buffer[target]
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['anarchism', 'as', 'originated', 'a', 'term', 'as', 'a', 'of']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['a', 'originated', 'anarchism', 'term', 'term', 'of', 'originated', 'as']

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default():

    # Input data.
    train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
    # Variables.
    embeddings = tf.Variable(
        tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    softmax_weights = tf.Variable(
        tf.truncated_normal([vocabulary_size, embedding_size],
                            stddev=1.0 / math.sqrt(embedding_size)))
    softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
    # Model.
    # Look up embeddings for inputs.
    embed = tf.nn.embedding_lookup(embeddings, train_dataset)
    # Compute the softmax loss, using a sample of the negative labels each time.
    loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

    # Optimizer.
    # Note: The optimizer will optimize the softmax_weights AND the embeddings.
    # This is because the embeddings are defined as a variable quantity and the
    # optimizer's `minimize` method will by default modify all variable quantities 
    # that contribute to the tensor it is passed.
    # See docs on `tf.train.Optimizer.minimize()` for more details.
    optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
    # Compute the similarity between minibatch examples and all embeddings.
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
    normalized_embeddings = embeddings / norm
    valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
    similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001
import time

t0 = time.time()
with tf.Session(config=tf.ConfigProto(log_device_placement=True), graph=graph) as session:
    tf.global_variables_initializer().run()
    print('Initialized')
    average_loss = 0
    for step in range(num_steps):
        batch_data, batch_labels = generate_batch(
            batch_size, num_skips, skip_window)
        feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
        _, l = session.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += l
        if step % 2000 == 0:
            if step > 0:
                average_loss = average_loss / 2000
                # The average loss is an estimate of the loss over the last 2000 batches.
                print('Average loss at step %d: %f' % (step, average_loss))
                average_loss = 0
            # note that this is expensive (~20% slowdown if computed every 500 steps)
            if step % 10000 == 0:
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = reverse_dictionary[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = reverse_dictionary[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
    final_embeddings = normalized_embeddings.eval()

t1 = time.time()

total = t1-t0
print('gpu-time', total)
# Out:
# Initialized
# Nearest to b: behold, surgeons, canoe, defer, metabolism, refuse, magician, enki,
# Nearest to eight: sel, tallest, expelling, floppies, mannered, mythic, roam, yeho,
# Nearest to if: highschool, opt, undesirable, jessie, strips, province, brings, interfering,
# Nearest to there: lettering, activities, tautology, goat, equilibria, queueing, binder, maude,
# Nearest to time: ietf, pong, architecturally, discontented, scavengers, curses, haul, elgin,
# Nearest to than: obstruct, gurney, categorically, seminary, omnipotence, justus, tabby, survivability,
# Nearest to in: protectionist, thither, leonidas, antoninus, chomsky, ilya, workbench, corpora,
# Nearest to all: fractions, allowable, fixture, hagar, spitfire, golfer, wracked, consumed,
# Nearest to with: deliberately, senussi, curtius, incisors, paradoxes, constantin, ills, anarchy,
# Nearest to who: nouakchott, knowledgeable, hoddle, chickasaw, badgers, denounced, bonded, billions,
# Nearest to up: convert, altruism, rand, championing, bonhomme, unveils, mango, holliday,
# Nearest to seven: mimas, erosion, implying, leroy, arid, navigate, reggio, darlington,
# Nearest to state: chamorro, infiltrate, ii, accelerations, nuncio, seifert, satie, dicotyledons,
# Nearest to been: shem, vibrant, eclipsed, caretaker, broader, diatonic, burner, mural,
# Nearest to by: wheelbase, hippolytus, transformers, morocco, measuring, colloquium, playback, pounder,
# Nearest to when: cth, governor, exclave, lucian, dalmatian, irrational, wig, stuttgart,
# Average loss at step 2000: 4.420410
# Average loss at step 4000: 3.910127
# Average loss at step 6000: 3.792340
# Average loss at step 8000: 3.754573
# Average loss at step 10000: 3.636499
# Nearest to b: surgeons, girardeau, behold, sadc, maddox, gridiron, balkans, auckland,
# Nearest to eight: six, nine, five, four, three, seven, two, one,
# Nearest to if: rhetorician, during, chambre, bibles, with, opt, occasional, lleyton,
# Nearest to there: it, they, often, cypriots, fabius, beelzebub, sparsely, audiogalaxy,
# Nearest to time: beneficiaries, sharif, elgin, extraordinary, name, strong, up, hitting,
# Nearest to than: screenwriter, unintelligent, ventilated, categorically, comma, tabby, israelis, mandan,
# Nearest to in: on, from, of, herat, at, protectionist, with, flock,
# Nearest to all: allowable, many, markus, doubleheader, believers, spitfire, stratified, structuralist,
# Nearest to with: in, for, as, between, and, or, thematic, without,
# Nearest to who: he, syndrome, caucasians, basalt, alexandros, dualism, intrusive, kay,
# Nearest to up: altruism, bonhomme, field, veganism, them, time, lafcadio, rand,
# Nearest to seven: four, five, six, eight, one, two, nine, three,
# Nearest to state: chamorro, infiltrate, ii, gertrude, seifert, carcass, portugu, walcott,
# Nearest to been: was, also, shem, aino, ashore, be, felsic, were,
# Nearest to by: be, into, as, tasting, was, for, moray, wheelbase,
# Nearest to when: and, while, disclosures, stoughton, bova, kenny, since, strapped,
# Average loss at step 12000: 3.638142
# Average loss at step 14000: 3.512611
# Average loss at step 16000: 3.618832
# Average loss at step 18000: 3.538541
# Average loss at step 20000: 3.514675
# Nearest to b: d, transuranic, auckland, correction, highbury, irwin, ksr, sanders,
# Nearest to eight: nine, six, seven, four, five, three, zero, two,
# Nearest to if: where, when, conceives, will, chambre, althing, refurbished, hazy,
# Nearest to there: they, it, he, still, often, cypriots, unable, but,
# Nearest to time: sharif, beneficiaries, year, name, hitting, strong, extraordinary, obeys,
# Nearest to than: or, but, unintelligent, ventilated, excludes, screenwriter, much, abound,
# Nearest to in: at, during, of, from, for, with, as, herat,
# Nearest to all: many, some, these, portuguese, rhetorician, stratified, archiving, mine,
# Nearest to with: in, between, by, at, for, through, as, into,
# Nearest to who: he, they, which, caucasians, adventurous, she, also, lycanthropy,
# Nearest to up: them, altruism, out, field, bonhomme, together, notables, gaseous,
# Nearest to seven: six, eight, nine, five, four, three, zero, one,
# Nearest to state: chamorro, infiltrate, walcott, doctor, ii, dicotyledons, portugu, aspects,
# Nearest to been: be, was, become, shem, aino, ashore, vibrant, were,
# Nearest to by: be, into, with, as, was, ramakrishna, for, is,
# Nearest to when: while, after, disclosures, during, soften, if, since, but,
# Average loss at step 22000: 3.584943
# Average loss at step 24000: 3.521929
# Average loss at step 26000: 3.408287
# Average loss at step 28000: 3.489803
# Average loss at step 30000: 3.474741
# Nearest to b: d, auckland, hermaphrodite, irwin, weekly, inventors, surgeons, hern,
# Nearest to eight: seven, nine, six, five, four, three, zero, two,
# Nearest to if: when, where, can, is, will, grote, could, since,
# Nearest to there: they, it, he, still, often, she, but, replicate,
# Nearest to time: year, sharif, hitting, name, extraordinary, beneficiaries, obeys, harmala,
# Nearest to than: but, or, ventilated, nucleotides, pod, screenwriter, and, unintelligent,
# Nearest to in: during, on, at, of, protectionist, within, when, for,
# Nearest to all: some, many, these, rhetorician, help, cumberland, lust, any,
# Nearest to with: between, for, in, culinary, through, without, crustaceans, by,
# Nearest to who: he, they, adventurous, also, she, caucasians, dualism, which,
# Nearest to up: out, them, altruism, bonhomme, him, together, notables, touch,
# Nearest to seven: eight, nine, six, five, four, three, zero, two,
# Nearest to state: chamorro, walcott, whistleblower, dicotyledons, infiltrate, university, concurrently, doctor,
# Nearest to been: become, were, be, aino, was, shem, ashore, had,
# Nearest to by: from, into, was, as, for, biomass, through, irc,
# Nearest to when: while, if, although, after, since, where, soften, in,
# Average loss at step 32000: 3.486659
# Average loss at step 34000: 3.492763
# Average loss at step 36000: 3.455221
# Average loss at step 38000: 3.476167
# Average loss at step 40000: 3.367251
# Nearest to b: d, auckland, hermaphrodite, weekly, tubing, joanne, jumbled, player,
# Nearest to eight: seven, nine, five, six, four, three, zero, two,
# Nearest to if: when, where, since, while, can, though, before, will,
# Nearest to there: they, it, he, still, often, she, now, which,
# Nearest to time: year, hitting, extraordinary, day, imitate, beneficiaries, name, hou,
# Nearest to than: or, slightly, excludes, nucleotides, ventilated, much, screenwriter, conscripts,
# Nearest to in: within, during, at, on, between, under, among, of,
# Nearest to all: many, some, these, any, various, rhetorician, translation, those,
# Nearest to with: between, in, crustaceans, through, assailant, deliberately, by, cheerleaders,
# Nearest to who: he, also, they, which, she, adventurous, already, caucasians,
# Nearest to up: out, altruism, off, them, him, together, touch, astra,
# Nearest to seven: eight, five, six, nine, four, three, zero, two,
# Nearest to state: walcott, whistleblower, chamorro, dicotyledons, waterway, britanniae, infancy, annex,
# Nearest to been: become, be, were, was, aino, ashore, stillborn, had,
# Nearest to by: biomass, ramakrishna, wilford, through, under, into, prussian, irc,
# Nearest to when: if, while, where, although, after, during, before, since,
# Average loss at step 42000: 3.315940
# Average loss at step 44000: 3.449460
# Average loss at step 46000: 3.330835
# Average loss at step 48000: 3.346174
# Average loss at step 50000: 3.383691
# Nearest to b: d, auckland, player, ksr, kursk, abrams, hern, irwin,
# Nearest to eight: four, five, nine, six, seven, zero, three, two,
# Nearest to if: when, where, refurbished, for, today, since, could, sutcliffe,
# Nearest to there: they, it, he, we, now, she, usually, still,
# Nearest to time: hitting, year, extraordinary, name, sharif, check, beneficiaries, day,
# Nearest to than: much, excludes, or, unlike, slightly, ventilated, conscripts, screenwriter,
# Nearest to in: at, during, from, on, within, with, under, of,
# Nearest to all: many, some, both, these, several, various, help, those,
# Nearest to with: between, through, in, by, into, mess, roche, slayer,
# Nearest to who: he, she, also, which, and, already, they, caucasians,
# Nearest to up: off, out, him, back, them, altruism, together, astra,
# Nearest to seven: five, six, four, nine, eight, three, zero, two,
# Nearest to state: dicotyledons, walcott, chamorro, conductor, whistleblower, system, britanniae, kiev,
# Nearest to been: become, be, aino, were, was, stillborn, had, ashore,
# Nearest to by: under, ramakrishna, through, moray, with, wilford, legitimized, into,
# Nearest to when: if, after, before, while, where, although, during, since,
# Average loss at step 52000: 3.331428
# Average loss at step 54000: 3.456782
# Average loss at step 56000: 3.392883
# Average loss at step 58000: 3.393117
# Average loss at step 60000: 3.173817
# Nearest to b: d, auckland, ksr, hern, boulders, f, cdot, dos,
# Nearest to eight: six, seven, five, four, nine, three, zero, two,
# Nearest to if: when, where, though, although, while, before, today, but,
# Nearest to there: they, it, she, he, now, still, we, usually,
# Nearest to time: hitting, year, day, harmala, extraordinary, period, domicile, name,
# Nearest to than: but, slightly, much, or, excludes, flasks, nucleotides, pod,
# Nearest to in: on, during, within, under, since, until, between, glorioso,
# Nearest to all: both, many, some, these, any, several, various, those,
# Nearest to with: between, through, attacker, and, laud, devotee, when, against,
# Nearest to who: he, they, already, she, there, adventurous, also, which,
# Nearest to up: out, off, them, him, altruism, back, together, down,
# Nearest to seven: eight, six, five, four, nine, three, two, one,
# Nearest to state: government, walcott, states, whistleblower, chamorro, infancy, dicotyledons, national,
# Nearest to been: become, be, was, were, aino, stillborn, aachen, wrap,
# Nearest to by: during, through, ramakrishna, was, wilford, konrad, prussian, concise,
# Nearest to when: if, while, although, after, where, before, during, until,
# Average loss at step 62000: 3.422164
# Average loss at step 64000: 3.382834
# Average loss at step 66000: 3.412725
# Average loss at step 68000: 3.420018
# Average loss at step 70000: 3.404957
# Nearest to b: d, auckland, ksr, r, c, cdot, astrological, ihr,
# Nearest to eight: nine, seven, six, five, four, three, two, zero,
# Nearest to if: when, where, though, for, sutcliffe, redrawn, immanuel, refurbished,
# Nearest to there: they, it, he, still, we, she, often, usually,
# Nearest to time: day, year, domicile, hitting, imitate, unskilled, hou, pagans,
# Nearest to than: or, but, much, unlike, jennings, excludes, rumor, slightly,
# Nearest to in: within, at, during, on, protectionist, from, between, with,
# Nearest to all: both, many, some, various, any, these, several, help,
# Nearest to with: between, in, gilda, for, among, slayer, by, through,
# Nearest to who: he, which, often, already, she, also, adventurous, and,
# Nearest to up: off, out, back, him, down, them, altruism, together,
# Nearest to seven: eight, six, nine, five, three, four, two, zero,
# Nearest to state: government, walcott, states, infancy, whistleblower, chamorro, commutes, britanniae,
# Nearest to been: become, be, were, was, aino, already, being, aachen,
# Nearest to by: ramakrishna, using, manitoba, vault, kowalski, prussian, wilford, was,
# Nearest to when: if, although, while, where, before, after, during, though,
# Average loss at step 72000: 3.377226
# Average loss at step 74000: 3.258559
# Average loss at step 76000: 3.358468
# Average loss at step 78000: 3.385532
# Average loss at step 80000: 3.351002
# Nearest to b: d, p, c, r, k, cdot, auckland, astrological,
# Nearest to eight: nine, six, seven, four, five, three, two, zero,
# Nearest to if: when, where, though, before, since, redrawn, while, after,
# Nearest to there: they, it, he, she, still, we, replicate, now,
# Nearest to time: day, harmala, year, domicile, extraordinary, pagans, name, unskilled,
# Nearest to than: or, but, jennings, slightly, unlike, pod, much, conscripts,
# Nearest to in: during, within, at, on, of, with, from, and,
# Nearest to all: many, some, both, various, any, several, every, these,
# Nearest to with: between, in, gilda, through, among, by, against, for,
# Nearest to who: they, which, also, often, he, she, adventurous, still,
# Nearest to up: off, out, back, him, down, together, them, altruism,
# Nearest to seven: eight, six, nine, four, five, three, zero, two,
# Nearest to state: government, whistleblower, walcott, boundaries, states, circumflex, accelerations, infancy,
# Nearest to been: become, be, aino, was, were, already, stillborn, wrap,
# Nearest to by: ramakrishna, during, from, manitoba, vault, with, newly, concise,
# Nearest to when: if, where, although, while, before, after, during, because,
# Average loss at step 82000: 3.311345
# Average loss at step 84000: 3.358991
# Average loss at step 86000: 3.356360
# Average loss at step 88000: 3.375628
# Average loss at step 90000: 3.367335
# Nearest to b: d, c, p, k, x, r, f, cdot,
# Nearest to eight: six, nine, seven, five, four, three, zero, two,
# Nearest to if: when, where, though, before, while, although, immanuel, since,
# Nearest to there: it, they, we, she, he, still, usually, often,
# Nearest to time: year, harmala, day, domicile, pagans, shelters, bronzes, unskilled,
# Nearest to than: but, or, slightly, much, unlike, jennings, flasks, pero,
# Nearest to in: during, within, at, until, of, near, on, among,
# Nearest to all: some, both, many, various, any, several, most, help,
# Nearest to with: between, among, culinary, devotee, attacker, enumerated, in, when,
# Nearest to who: he, never, often, which, she, they, adventurous, still,
# Nearest to up: off, out, back, them, him, together, down, altruism,
# Nearest to seven: eight, six, nine, five, four, zero, three, one,
# Nearest to state: government, circumflex, states, infancy, kaist, walcott, portugu, nuncio,
# Nearest to been: become, be, were, aino, traditionally, already, previously, was,
# Nearest to by: vault, newly, ramakrishna, through, biomass, discontented, dorsal, nsync,
# Nearest to when: if, where, although, while, after, before, because, though,
# Average loss at step 92000: 3.287947
# Average loss at step 94000: 3.249553
# Average loss at step 96000: 3.334415
# Average loss at step 98000: 3.294343
# Average loss at step 100000: 3.316476
# Nearest to b: d, p, c, f, bambaataa, ksr, handset, stipulated,
# Nearest to eight: nine, five, seven, six, three, four, zero, two,
# Nearest to if: when, though, where, before, while, after, since, although,
# Nearest to there: they, it, she, we, he, now, still, which,
# Nearest to time: harmala, year, pagans, day, domicile, hitting, unskilled, bronzes,
# Nearest to than: much, but, or, slightly, unlike, jennings, conscripts, pero,
# Nearest to in: within, during, on, among, of, transuranic, with, for,
# Nearest to all: both, various, some, many, stab, any, every, several,
# Nearest to with: between, https, in, culinary, plus, without, among, crustaceans,
# Nearest to who: he, never, which, they, often, she, probably, still,
# Nearest to up: off, out, back, them, together, him, down, altruism,
# Nearest to seven: five, nine, eight, six, four, three, two, zero,
# Nearest to state: government, states, national, circumflex, constitution, boundaries, conductor, infancy,
# Nearest to been: become, be, was, aino, traditionally, were, already, aachen,
# Nearest to by: wilford, ramakrishna, through, astrologers, nsync, as, when, vault,
# Nearest to when: if, although, after, before, while, where, though, during,
# gpu-time 195.49108171463013

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

    # Input data.
    train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
    # Variables.
    embeddings = tf.Variable(
        tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    softmax_weights = tf.Variable(
        tf.truncated_normal([vocabulary_size, embedding_size],
                            stddev=1.0 / math.sqrt(embedding_size)))
    softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
    # Model.
    # Look up embeddings for inputs.
    embed = tf.nn.embedding_lookup(embeddings, train_dataset)
    # Compute the softmax loss, using a sample of the negative labels each time.
    loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

    # Optimizer.
    # Note: The optimizer will optimize the softmax_weights AND the embeddings.
    # This is because the embeddings are defined as a variable quantity and the
    # optimizer's `minimize` method will by default modify all variable quantities 
    # that contribute to the tensor it is passed.
    # See docs on `tf.train.Optimizer.minimize()` for more details.
    optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
    # Compute the similarity between minibatch examples and all embeddings.
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
    normalized_embeddings = embeddings / norm
    valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
    similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001
import time

t0 = time.time()
with tf.Session(config=tf.ConfigProto(log_device_placement=True), graph=graph) as session:
    tf.global_variables_initializer().run()
    print('Initialized')
    average_loss = 0
    for step in range(num_steps):
        batch_data, batch_labels = generate_batch(
            batch_size, num_skips, skip_window)
        feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
        _, l = session.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += l
        if step % 2000 == 0:
            if step > 0:
                average_loss = average_loss / 2000
                # The average loss is an estimate of the loss over the last 2000 batches.
                print('Average loss at step %d: %f' % (step, average_loss))
                average_loss = 0
            # note that this is expensive (~20% slowdown if computed every 500 steps)
            if step % 10000 == 0:
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = reverse_dictionary[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = reverse_dictionary[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
    final_embeddings = normalized_embeddings.eval()

t1 = time.time()

total = t1-t0
print('cpu-time', total)
# Out:
# Initialized
# Nearest to th: petitioner, lise, ill, turbocharged, lied, nnrot, ayyash, ramayana,
# Nearest to from: paulsen, ephemeral, istv, bretwalda, naur, geese, oakland, horatio,
# Nearest to with: kangaroo, datum, outs, existed, showdown, hooper, cretaceous, satirize,
# Nearest to this: atkinson, dignitaries, avengers, academy, festus, lazuli, intellect, rowland,
# Nearest to on: privatizing, experiments, boarder, daphne, struggling, employees, postalveolar, polemics,
# Nearest to their: prayed, weeds, transparency, ligase, downed, branson, wills, tipped,
# Nearest to seven: retreat, ssri, pyrenees, suse, labs, makes, evocative, mozambican,
# Nearest to these: sark, alerting, tua, reptiles, verify, ipf, pindar, structures,
# Nearest to use: irb, roxbury, operetta, disestablishment, gentle, cassidy, oranges, rance,
# Nearest to also: allegiance, lct, convex, teau, monitoring, clockless, minting, heroically,
# Nearest to and: intifada, lady, transsexual, lenses, whale, specifying, measles, roundel,
# Nearest to b: clos, distancing, young, opal, frightened, truly, cake, davy,
# Nearest to six: lances, namesake, schopenhauer, pardon, echoing, umpires, flutie, compliant,
# Nearest to was: lucie, rlc, rosamund, adolph, participation, islami, pdg, spill,
# Nearest to many: troughs, sari, slovenes, salt, granary, collision, angelica, tumor,
# Nearest to his: whatever, ejaculate, presupposition, belfry, gita, elsewhere, yana, galil,
# Average loss at step 2000: 4.384477
# Average loss at step 4000: 3.889435
# Average loss at step 6000: 3.621098
# Average loss at step 8000: 3.135549
# Average loss at step 10000: 3.364930
# Nearest to th: lise, ayyash, ill, dayan, nnrot, habermas, petitioner, turbocharged,
# Nearest to from: for, including, by, of, in, to, marrow, into,
# Nearest to with: for, through, between, outs, declensions, in, jong, mallarm,
# Nearest to this: the, his, a, which, usually, it, conspicuous, pekka,
# Nearest to on: in, screens, regiments, at, from, dyslexic, during, into,
# Nearest to their: his, its, the, prayed, ligase, harmony, a, this,
# Nearest to seven: eight, six, five, nine, four, three, zero, two,
# Nearest to these: some, ziegler, pindar, stonewall, ipf, stub, disband, sark,
# Nearest to use: irb, df, infusions, releases, mesh, doomsday, butlerian, bartholomew,
# Nearest to also: he, not, clique, you, missoula, broker, ethiopians, burden,
# Nearest to and: b, or, american, d, english, proprietor, isaak, which,
# Nearest to b: d, and, davy, johore, opal, meuse, joanna, herrings,
# Nearest to six: eight, five, seven, four, nine, three, zero, two,
# Nearest to was: is, had, were, has, are, as, be, by,
# Nearest to many: troughs, granary, gnat, americo, all, salt, amygdala, plot,
# Nearest to his: their, the, its, s, her, this, yana, cultural,
# Average loss at step 12000: 3.347553
# Average loss at step 14000: 3.501128
# Average loss at step 16000: 3.518736
# Average loss at step 18000: 3.509719
# Average loss at step 20000: 3.476457
# Nearest to th: turbocharged, nnrot, dayan, sympathetic, habermas, lise, crystalline, ill,
# Nearest to from: including, into, in, by, and, of, were, under,
# Nearest to with: between, and, by, through, transsexual, bucaram, showdown, bouncing,
# Nearest to this: it, which, the, that, a, usually, his, conspicuous,
# Nearest to on: in, during, at, dyslexic, from, regiments, around, into,
# Nearest to their: its, his, the, her, prayed, s, unqualified, these,
# Nearest to seven: six, eight, four, nine, five, three, zero, one,
# Nearest to these: some, which, several, are, all, stonewall, stub, many,
# Nearest to use: haram, kelvins, doomsday, mesh, butlerian, continuously, irb, bullying,
# Nearest to also: which, often, it, that, oldies, there, aerobic, largely,
# Nearest to and: or, but, with, which, from, in, warners, harem,
# Nearest to b: d, podcast, davy, psi, integrates, opal, tinymud, spandau,
# Nearest to six: seven, eight, five, four, nine, three, zero, two,
# Nearest to was: is, were, had, has, been, be, are, became,
# Nearest to many: some, several, different, such, those, these, salt, much,
# Nearest to his: their, her, its, the, s, ifvs, this, my,
# Average loss at step 22000: 3.525334
# Average loss at step 24000: 3.554662
# Average loss at step 26000: 3.524133
# Average loss at step 28000: 3.542333
# Average loss at step 30000: 3.361257
# Nearest to th: turbocharged, nnrot, four, tld, cin, sympathetic, isbn, fughetta,
# Nearest to from: into, including, in, denoting, understands, swallowed, through, computationally,
# Nearest to with: between, milieu, bucaram, and, reactions, through, sukhum, showdown,
# Nearest to this: which, the, it, that, another, nigeria, conspicuous, ergonomics,
# Nearest to on: in, during, upon, for, off, through, dyslexic, marcian,
# Nearest to their: its, his, her, our, scenes, westmoreland, these, regalia,
# Nearest to seven: eight, six, four, three, nine, five, zero, two,
# Nearest to these: some, many, several, all, such, which, angevin, other,
# Nearest to use: mesh, kelvins, doomsday, duval, haram, soulful, development, variety,
# Nearest to also: which, often, that, still, largely, it, there, mitochondria,
# Nearest to and: or, worldcon, but, with, for, burlesque, jeffersonian, eco,
# Nearest to b: d, davy, psi, mayonnaise, m, podcast, rats, n,
# Nearest to six: seven, five, eight, three, four, nine, zero, two,
# Nearest to was: is, were, has, had, became, kinases, be, when,
# Nearest to many: some, several, these, all, different, those, such, various,
# Nearest to his: her, their, its, my, your, reciprocate, ambassadors, unfold,
# Average loss at step 32000: 3.375630
# Average loss at step 34000: 3.490998
# Average loss at step 36000: 3.452309
# Average loss at step 38000: 3.446574
# Average loss at step 40000: 3.443036
# Nearest to th: rd, sympathetic, dayan, turbocharged, one, tld, isbn, nnrot,
# Nearest to from: into, including, denoting, of, reconquer, marrow, by, paulsen,
# Nearest to with: between, by, when, showdown, using, mallarm, through, in,
# Nearest to this: which, the, it, another, that, any, env, his,
# Nearest to on: upon, during, in, at, around, dyslexic, connor, corporation,
# Nearest to their: its, his, her, the, our, your, some, westmoreland,
# Nearest to seven: six, eight, five, four, nine, three, one, zero,
# Nearest to these: some, many, several, such, those, various, which, angevin,
# Nearest to use: kelvins, huber, haram, forecasts, duval, mesh, center, modifications,
# Nearest to also: often, which, still, it, who, totally, now, largely,
# Nearest to and: or, but, although, including, of, when, for, however,
# Nearest to b: d, n, c, rats, podcast, dysprosium, x, e,
# Nearest to six: five, seven, eight, four, nine, three, two, zero,
# Nearest to was: is, were, had, became, has, been, be, when,
# Nearest to many: some, several, these, various, all, those, washed, most,
# Nearest to his: her, their, its, my, the, your, whose, ambassadors,
# Average loss at step 42000: 3.486082
# Average loss at step 44000: 3.411947
# Average loss at step 46000: 3.359165
# Average loss at step 48000: 3.081185
# Average loss at step 50000: 3.367176
# Nearest to th: rd, sympathetic, nnrot, dayan, khz, skye, lise, subtended,
# Nearest to from: into, through, denoting, understands, on, in, by, reconquer,
# Nearest to with: between, by, seidel, yd, prosper, despite, guard, through,
# Nearest to this: which, it, the, that, another, any, env, his,
# Nearest to on: upon, through, during, in, around, sheet, at, off,
# Nearest to their: its, his, her, the, these, our, your, lotta,
# Nearest to seven: eight, six, four, nine, five, three, zero, two,
# Nearest to these: many, some, such, several, those, various, different, both,
# Nearest to use: kelvins, mesh, end, support, popularity, doomsday, duval, variety,
# Nearest to also: often, now, still, which, it, sometimes, totally, never,
# Nearest to and: or, but, of, like, for, s, theodore, in,
# Nearest to b: d, davy, podcast, messalina, garbage, c, delicacy, dynamite,
# Nearest to six: eight, seven, nine, four, three, five, two, zero,
# Nearest to was: is, has, were, had, became, when, be, being,
# Nearest to many: some, several, these, various, those, all, most, both,
# Nearest to his: her, their, its, my, the, your, s, ambassadors,
# Average loss at step 52000: 3.379145
# Average loss at step 54000: 3.201057
# Average loss at step 56000: 3.380318
# Average loss at step 58000: 3.478155
# Average loss at step 60000: 3.397276
# Nearest to th: rd, khz, one, tld, sympathetic, princess, leeward, twentieth,
# Nearest to from: into, through, in, denoting, including, understands, during, computationally,
# Nearest to with: between, by, in, jong, mallarm, through, orangutan, while,
# Nearest to this: which, it, that, each, what, any, some, predynastic,
# Nearest to on: upon, in, through, around, at, during, dyslexic, marginalized,
# Nearest to their: its, his, her, the, your, these, my, our,
# Nearest to seven: eight, nine, five, six, four, three, zero, two,
# Nearest to these: several, some, many, those, such, their, various, which,
# Nearest to use: kelvins, popularity, end, mesh, forecasts, support, study, variety,
# Nearest to also: often, still, now, which, typically, sometimes, commonly, never,
# Nearest to and: or, but, including, charioteer, swim, however, while, in,
# Nearest to b: d, podcast, blitter, davy, messalina, tripled, sonatas, delicacy,
# Nearest to six: eight, five, seven, four, nine, three, zero, two,
# Nearest to was: is, were, had, became, has, when, while, did,
# Nearest to many: some, several, various, these, those, most, all, washed,
# Nearest to his: her, their, its, my, your, the, whose, piranha,
# Average loss at step 62000: 3.234232
# Average loss at step 64000: 3.320226
# Average loss at step 66000: 3.395830
# Average loss at step 68000: 3.430840
# Average loss at step 70000: 3.418781
# Nearest to th: rd, khz, tld, twentieth, six, second, sympathetic, ce,
# Nearest to from: through, into, in, understands, including, denoting, during, under,
# Nearest to with: between, among, in, when, including, through, while, seidel,
# Nearest to this: it, which, the, his, each, another, env, any,
# Nearest to on: upon, in, through, during, at, against, and, slit,
# Nearest to their: its, his, her, our, your, the, these, some,
# Nearest to seven: five, four, nine, six, eight, three, one, zero,
# Nearest to these: many, several, some, such, those, their, various, both,
# Nearest to use: kelvins, popularity, end, support, huber, mesh, duval, doomsday,
# Nearest to also: now, often, still, sometimes, never, which, commonly, typically,
# Nearest to and: or, but, although, however, including, while, when, on,
# Nearest to b: d, podcast, blitter, davy, messalina, addams, nchez, psi,
# Nearest to six: seven, five, four, eight, nine, three, zero, one,
# Nearest to was: is, became, were, had, when, has, by, be,
# Nearest to many: some, several, various, these, both, those, all, most,
# Nearest to his: her, their, its, my, the, your, this, s,
# Average loss at step 72000: 3.373468
# Average loss at step 74000: 3.319969
# Average loss at step 76000: 3.381345
# Average loss at step 78000: 3.290660
# Average loss at step 80000: 3.353347
# Nearest to th: rd, bc, khz, tld, seven, ce, ad, twentieth,
# Nearest to from: into, through, denoting, reconquer, in, computationally, during, fictional,
# Nearest to with: between, cretaceous, bucaram, bromley, in, guard, when, protozoa,
# Nearest to this: it, which, any, the, another, each, some, what,
# Nearest to on: upon, through, in, marginalized, during, about, near, around,
# Nearest to their: its, her, his, our, your, the, whose, these,
# Nearest to seven: eight, six, four, nine, five, three, zero, two,
# Nearest to these: several, those, many, some, various, such, both, they,
# Nearest to use: kelvins, popularity, study, huber, wane, bullying, support, niches,
# Nearest to also: often, now, still, typically, sometimes, commonly, usually, below,
# Nearest to and: or, but, like, although, however, including, worldcon, while,
# Nearest to b: d, blitter, podcast, musician, davy, garbage, scholastic, mellor,
# Nearest to six: five, seven, four, eight, nine, three, zero, two,
# Nearest to was: is, were, became, had, has, be, been, although,
# Nearest to many: some, several, various, most, both, all, these, those,
# Nearest to his: her, their, my, its, your, our, ambassadors, whose,
# Average loss at step 82000: 3.325396
# Average loss at step 84000: 3.265498
# Average loss at step 86000: 3.215710
# Average loss at step 88000: 3.296633
# Average loss at step 90000: 3.324705
# Nearest to th: rd, third, second, ce, twentieth, fifth, khz, bc,
# Nearest to from: through, into, in, under, denoting, during, to, understands,
# Nearest to with: between, despite, goeldi, by, jong, mallarm, in, among,
# Nearest to this: which, it, another, the, what, some, predynastic, any,
# Nearest to on: upon, through, in, during, dyslexic, dissolves, at, near,
# Nearest to their: its, his, her, our, the, your, my, them,
# Nearest to seven: eight, six, five, four, nine, three, zero, two,
# Nearest to these: several, such, some, many, those, various, which, both,
# Nearest to use: kelvins, support, niches, study, goldfish, popularity, doomsday, most,
# Nearest to also: now, often, typically, still, which, actually, sometimes, usually,
# Nearest to and: or, but, although, however, including, worldcon, like, which,
# Nearest to b: d, podcast, integrates, blitter, musician, booms, davy, messalina,
# Nearest to six: eight, four, seven, nine, three, five, two, zero,
# Nearest to was: is, had, has, became, although, were, becomes, be,
# Nearest to many: some, several, various, both, these, those, most, all,
# Nearest to his: her, their, my, its, your, whose, our, the,
# Average loss at step 92000: 3.315916
# Average loss at step 94000: 3.285801
# Average loss at step 96000: 3.343837
# Average loss at step 98000: 3.309423
# Average loss at step 100000: 3.365383
# Nearest to th: rd, ce, third, bc, khz, second, nd, twentieth,
# Nearest to from: into, through, under, denoting, in, understands, including, during,
# Nearest to with: between, under, in, without, among, bucaram, for, including,
# Nearest to this: which, it, another, what, that, predynastic, the, any,
# Nearest to on: upon, through, in, around, within, about, toward, during,
# Nearest to their: its, his, her, your, our, the, these, whose,
# Nearest to seven: eight, six, five, nine, four, three, zero, two,
# Nearest to these: some, several, many, those, such, both, various, they,
# Nearest to use: most, kelvins, niches, wane, support, goldfish, study, form,
# Nearest to also: now, often, still, typically, actually, sometimes, never, who,
# Nearest to and: or, but, including, of, however, in, although, worldcon,
# Nearest to b: d, libels, podcast, davy, galvanized, tramiel, integrates, blitter,
# Nearest to six: eight, seven, five, four, nine, three, zero, two,
# Nearest to was: is, became, were, had, has, becomes, been, while,
# Nearest to many: some, several, various, these, those, both, most, all,
# Nearest to his: her, their, my, its, your, our, ambassadors, whose,
# cpu-time 218.67738938331604
